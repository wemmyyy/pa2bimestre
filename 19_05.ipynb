# %% [markdown]
# <a href="https://colab.research.google.com/github/wemmyyy/pa2bimestre/blob/main/19_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **laços de iteração**
#
# for - geralmente é utilizaso quando sabemos quantas vezes algo vai se repetir
#
# while - é usado quando nao sabemos.
# ```

# %%
senha = " "

while senha != 1234:
  senha = int(input("digite sua senha: "))
  print("senha invalida.")

print("Acesso liberado.")

# %%
for i in range (5):
  print (i)

# %%
contador = 0

while contador < 5:
  print (contador)
  contador +=1

# %%
#contagem regressiva de 10 ate 0

contador = 10

while contador >= 0:
  print (contador)
  contador -=1

# %%
nota = 0
resultado = 0
bimestre = 1

while bimestre <= 4:
  nota = float(input(f"digite sua nota do {bimestre}º bimestre: "))
  bimestre +=1
  resultado = resultado+nota
print(f"sua media é: {resultado}")

media = resultado / 4

if media >= 7:
  print("aprovado")

elif media >= 5:
  print("recuperação")

elif media <=4:
  print("reprovado")
